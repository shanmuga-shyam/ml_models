# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_excel(r"C:\Users\Shanmuga Shyam. B\OneDrive\Desktop\ml-learn\linear_regression\linear_example.xlsx")
df
# Out:
#    area  price
# 0  2600  50000
# 1  3000  60000
# 2  3200  70000
# 3  3600  80000
# 4  4000  90000

# %%
reg = linear_model.LinearRegression()
reg.fit(df[["area"]],df.price)
# Out:
# LinearRegression()

# %%
plt.scatter(df.area,df.price,color="red",marker="+")
plt.xlabel("area",fontsize=20)
plt.ylabel("price",fontsize=20)
plt.plot(df.area,reg.predict(df[["area"]]),color="teal")

# %%
import pickle
with open("model_pickel","wb") as f:
    pickle.dump(reg,f)
with open("model_pickel","rb") as f:
    mp = pickle.load(f)

# %%
mp.predict(pd.DataFrame({"area":[2000]}))
# Out:
# array([32739.7260274])

# %%
import joblib
joblib.dump(reg,"model_saveby_joblib.pkl")
loaded_model = joblib.load("model_saveby_joblib.pkl")

# %%
loaded_model([[200]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 loaded_model([[200]])
#
# TypeError: 'LinearRegression' object is not callable
