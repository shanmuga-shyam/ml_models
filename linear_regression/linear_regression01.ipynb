# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_excel("C:/Users/Shanmuga Shyam. B/OneDrive/Documents/linear_example.xlsx")
df
# Out:
#    area  price
# 0  2600  50000
# 1  3000  60000
# 2  3200  70000
# 3  3600  80000
# 4  4000  90000

# %%
plt.scatter(df.area,df.price)

# %%
plt.scatter(df.area,df.price,color="red",marker="+")

# %%
plt.xlabel("area(sq ft)", fontsize = 20)
plt.ylabel("price(rupee)", fontsize = 20)
plt.scatter(df.area,df.price,color="red",marker="+")
plt.plot(df.area,reg.predict(df[["area"]]),color = "blue")#blue line

# %%
reg = linear_model.w()
reg.fit(df[["area"]],df.price)
# Out:
# LinearRegression()

# %%
x = 5000
reg.predict(pd.DataFrame({"area":[x]}))
x
# Out:
# 5000

# %%
#there is a formula for linear regression is y = mx+b that is price = m*area+b
m = reg.coef_ # shows the value of m
m
# Out:
# array([29.10958904])

# %%
b = reg.intercept_ # shows the value of the b
b
# Out:
# -25479.45205479453

# %%
#y=m*x+b
m*x+b
# Out:
# array([120068.49315068])

# %%
d = read_excel("C:\Users\Shanmuga Shyam. B\OneDrive\Desktop\ml-learn\linear_test.xlsx")
d

# %%
p = reg.predict(d)

# %%
d["price"] = p
d
# Out:
#    area          price
# 0  3100   64760.273973
# 1  3150   66215.753425
# 2  2600   50205.479452
# 3  3900   88047.945205
# 4   352  -15232.876712
# 5  4242   98003.424658
# 6  2424   45082.191781
# 7  2564   49157.534247
# 8  6743  170806.506849
# 9  5563  136457.191781

# %%
d.to_excel("C:/Users/Shanmuga Shyam. B/OneDrive/Documents/linear_test.xlsx")
